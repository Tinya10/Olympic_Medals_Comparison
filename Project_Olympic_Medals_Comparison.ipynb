# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("G:\Data Science ML AI\Python files\Projects\Project_Olympic_Hero\Olympic_dataset.csv")
data.head(20)
# Out:
#            Country_Name  # Summer  Gold_Summer  Silver_Summer  Bronze_Summer  \
# 0           Afghanistan        13            0              0              2
# 1               Algeria        12            5              2              8
# 2             Argentina        23           18             24             28
# 3               Armenia         5            1              2              9
# 4           Australasia         2            3              4              5
# 5             Australia        25          139            152            177
# 6               Austria        26           18             33             35
# 7            Azerbaijan         5            6              5             15
# 8               Bahamas        15            5              2              5
# 9               Bahrain         8            0              0              1
# 10             Barbados        11            0              0              1
# ...

# %%
#Renaming a column
data.rename(columns = {'Total':'Total_Medals'},inplace=True)
data.head(5)
# Out:
#   Country_Name  # Summer  Gold_Summer  Silver_Summer  Bronze_Summer  \
# 0  Afghanistan        13            0              0              2
# 1      Algeria        12            5              2              8
# 2    Argentina        23           18             24             28
# 3      Armenia         5            1              2              9
# 4  Australasia         2            3              4              5
#
#    Total_Summer  # Winter  Gold_Winter  Silver_Winter  Bronze_Winter  \
# 0             2         0            0              0              0
# 1            15         3            0              0              0
# 2            70        18            0              0              0
# 3            12         6            0              0              0
# 4            12         0            0              0              0
#
#    Total_Winter  # Games  Gold_Total  Silver_Total  Bronze_Total  Total_Medals
# ...

# %%
#Creating new column 'Better_Event'
data['Better_Event'] = np.where(data['Total_Summer']>data['Total_Winter'],'Summer','Winter')
data['Better_Event'] = np.where(data['Total_Summer'] == data['Total_Winter'],'Both',data['Better_Event'])
data.head(20)
# Out:
#            Country_Name  # Summer  Gold_Summer  Silver_Summer  Bronze_Summer  \
# 0           Afghanistan        13            0              0              2
# 1               Algeria        12            5              2              8
# 2             Argentina        23           18             24             28
# 3               Armenia         5            1              2              9
# 4           Australasia         2            3              4              5
# 5             Australia        25          139            152            177
# 6               Austria        26           18             33             35
# 7            Azerbaijan         5            6              5             15
# 8               Bahamas        15            5              2              5
# 9               Bahrain         8            0              0              1
# 10             Barbados        11            0              0              1
# ...

# %%
#Finding the value with max count in 'Better_Event' column
better_event = data['Better_Event'].value_counts()
better_event
# Out:
# Summer    143
# Winter      3
# Both        1
# Name: Better_Event, dtype: int64

# %%
#findig the better event
better_event = data['Better_Event'].value_counts().idxmax()
print("The better event is", str(better_event),'Olympics')
# Out:
# The better event is Summer Olympics

# %%
#Finding the top 10 performing teams at summer event (with respect to total medals), winter event and overall
top_countries = data[["Country_Name","Total_Summer","Total_Winter","Total_Medals"]]
top_countries.head(10)
# Out:
#   Country_Name  Total_Summer  Total_Winter  Total_Medals
# 0  Afghanistan             2             0             2
# 1      Algeria            15             0            15
# 2    Argentina            70             0            70
# 3      Armenia            12             0            12
# 4  Australasia            12             0            12
# 5    Australia           468            12           480
# 6      Austria            86           218           304
# 7   Azerbaijan            26             0            26
# 8      Bahamas            12             0            12
# 9      Bahrain             1             0             1

# %%
#Dropping the last row as it includes total
top_countries = top_countries[:-1]
top_countries.tail()
# Out:
#                          Country_Name  Total_Summer  Total_Winter  \
# 140                    Virgin Islands             1             0
# 141                        Yugoslavia            83             4
# 142  Independent Olympic Participants             3             0
# 143                            Zambia             2             0
# 144                          Zimbabwe             8             0
#
#      Total_Medals
# 140             1
# 141            87
# 142             3
# 143             2
# 144             8

# %%
#Function for fetching top 10 countries
def top_ten(df,col1):
    
    #Creating a new list
    
    country_list = []
    
    #Finding the top 10 values of 'col' column
    country_list = list((df.nlargest(10,col1))['Country_Name'])
    
    return country_list

# %%
#Calling the function for Top 10 in Summer   
top_10_summer = top_ten(top_countries,'Total_Summer')
top_10_summer
# Out:
# ['United States',
#  'Soviet Union',
#  'Great Britain',
#  'France',
#  'Germany',
#  'Italy',
#  'Sweden',
#  'Hungary',
#  'China',
#  'Australia']

# %%
#Calling the function for Top 10 in Winter
top_10_winter = top_ten(top_countries,'Total_Winter')
top_10_winter
# Out:
# ['Norway',
#  'United States',
#  'Austria',
#  'Germany',
#  'Soviet Union',
#  'Canada',
#  'Finland',
#  'Sweden',
#  'Switzerland',
#  'Russia']

# %%
#Calling the function for Top 10 in both the events
top_10 = top_ten(top_countries,'Total_Medals')
top_10
# Out:
# ['United States',
#  'Soviet Union',
#  'Great Britain',
#  'Germany',
#  'France',
#  'Italy',
#  'Sweden',
#  'China',
#  'East Germany',
#  'Russia']

# %%
#Extracting common country names from all three lists
common_countries = list(set(top_10_summer) & set(top_10_winter) & set(top_10))
print("The winning countries in all three types of Olympics are",common_countries)
# Out:
# The winning countries in all three types of Olympics are ['Soviet Union', 'United States', 'Sweden', 'Germany']

# %%
#Creating the dataframe for Summer event
summer_df = data[data['Country_Name'].isin(top_10_summer)]
summer_df
# Out:
#       Country_Name  # Summer  Gold_Summer  Silver_Summer  Bronze_Summer  \
# 5        Australia        25          139            152            177
# 23           China         9          201            146            126
# 41          France        27          202            223            246
# 44         Germany        15          174            182            217
# 49   Great Britain        27          236            272            272
# 56         Hungary        25          167            144            165
# 64           Italy        26          198            166            185
# 106   Soviet Union         9          395            319            296
# 120         Sweden        26          143            164            176
# 135  United States        26          976            757            666
#
#      Total_Summer  # Winter  Gold_Winter  Silver_Winter  Bronze_Winter  \
# 5             468        18            5              3              4
# ...

# %%
#Plotting the bar graph for summer event
plt.figure(figsize=(20,6))
plt.bar(summer_df['Country_Name'],summer_df['Total_Summer'])
plt.title('Top 10 Countries in Summer Olympics')
plt.xlabel('Country Name')
plt.ylabel('Total Medals')
# Out:
# Text(0, 0.5, 'Total Medals')

# %%
#Creating the dataframe for Summer event
winter_df = data[data['Country_Name'].isin(top_10_winter)]
winter_df
# Out:
#       Country_Name  # Summer  Gold_Summer  Silver_Summer  Bronze_Summer  \
# 6          Austria        26           18             33             35
# 21          Canada        25           59             99            121
# 40         Finland        24          101             84            117
# 44         Germany        15          174            182            217
# 93          Norway        24           56             49             43
# 104         Russia         5          132            121            142
# 106   Soviet Union         9          395            319            296
# 120         Sweden        26          143            164            176
# 121    Switzerland        27           47             73             65
# 135  United States        26          976            757            666
#
#      Total_Summer  # Winter  Gold_Winter  Silver_Winter  Bronze_Winter  \
# 6              86        22           59             78             81
# ...

# %%
#Plotting the bar graph for winter event
plt.figure(figsize=(20,6))
plt.bar(winter_df['Country_Name'],winter_df['Total_Winter'])
plt.title('Top 10 Countries in Winter Olympics')
plt.xlabel('Country Name')
plt.ylabel('Total Medals')
# Out:
# Text(0, 0.5, 'Total Medals')

# %%
#Creating the dataframe for both event
top_df = data[data['Country_Name'].isin(top_10)]
top_df
# Out:
#       Country_Name  # Summer  Gold_Summer  Silver_Summer  Bronze_Summer  \
# 23           China         9          201            146            126
# 41          France        27          202            223            246
# 44         Germany        15          174            182            217
# 46    East Germany         5          153            129            127
# 49   Great Britain        27          236            272            272
# 64           Italy        26          198            166            185
# 104         Russia         5          132            121            142
# 106   Soviet Union         9          395            319            296
# 120         Sweden        26          143            164            176
# 135  United States        26          976            757            666
#
#      Total_Summer  # Winter  Gold_Winter  Silver_Winter  Bronze_Winter  \
# 23            473        10           12             22             19
# ...

# %%
#Plotting the bar graph for both events
plt.figure(figsize=(20,6))
plt.bar(top_df['Country_Name'],top_df['Total_Medals'])
plt.title('Top Countries in all Olympics')
plt.xlabel('Country Name')
plt.ylabel('Total Medals')
# Out:
# Text(0, 0.5, 'Total Medals')

# %%
#Finding which country has had the best performance with respect to the ratio between gold medals won and total medals won
summer_df['Golden_Ratio'] = summer_df['Gold_Summer']/summer_df['Total_Summer']
summer_df.head(5)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      Country_Name  # Summer  Gold_Summer  Silver_Summer  Bronze_Summer  \
# 5       Australia        25          139            152            177
# 23          China         9          201            146            126
# 41         France        27          202            223            246
# 44        Germany        15          174            182            217
# 49  Great Britain        27          236            272            272
#
#     Total_Summer  # Winter  Gold_Winter  Silver_Winter  Bronze_Winter  \
# 5            468        18            5              3              4
# ...

# %%
#Finding the max value of 'Golden_Ratio' column
summer_max_ratio = max(summer_df['Golden_Ratio'])
print("Maximum Golden Ration is",summer_max_ratio)

#Finding the country assosciated with the max value of 'Golden_Ratio' column
summer_country_gold = summer_df.loc[summer_df['Golden_Ratio'].idxmax(),'Country_Name']
print("Top Summer Country is",summer_country_gold,"with a ration of %.2f" %summer_max_ratio)
# Out:
# Maximum Golden Ration is 0.4249471458773784
# Top Summer Country is China with a ration of 0.42

# %%
#For Winter List
#Creating new column 'Golden_Ratio'
winter_df['Golden_Ratio'] = winter_df['Gold_Winter']/winter_df['Total_Winter']
winter_df
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       Country_Name  # Summer  Gold_Summer  Silver_Summer  Bronze_Summer  \
# 6          Austria        26           18             33             35
# 21          Canada        25           59             99            121
# 40         Finland        24          101             84            117
# 44         Germany        15          174            182            217
# 93          Norway        24           56             49             43
# 104         Russia         5          132            121            142
# ...

# %%
#Finding the max value of 'Golden_Ratio' column
winter_max_ratio = max(winter_df['Golden_Ratio'])
print("Maximum Gold Ratio is",winter_max_ratio)

winter_country_gold = winter_df.loc[winter_df['Golden_Ratio'].idxmax(),'Country_Name']
print("Top Country is",winter_country_gold,"with a ration of %.2f"%winter_max_ratio)
# Out:
# Maximum Gold Ratio is 0.4020618556701031
# Top Country is Soviet Union with a ration of 0.40

# %%
#For Overall List
#Creating new column 'Golden_Ratio'
top_df['Golden_Ratio'] = top_df['Gold_Total']/top_df['Total_Medals']
top_df
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       Country_Name  # Summer  Gold_Summer  Silver_Summer  Bronze_Summer  \
# 23           China         9          201            146            126
# 41          France        27          202            223            246
# 44         Germany        15          174            182            217
# 46    East Germany         5          153            129            127
# 49   Great Britain        27          236            272            272
# 64           Italy        26          198            166            185
# ...

# %%
#Finding the max value of 'Golden_Ratio' column
top_max_ratio = max(top_df['Golden_Ratio'])
print('Maximum Gold Ratio is',top_max_ratio)

#Finding the country assosciated with the max value of 'Golden_Ratio' column
top_country_gold = top_df.loc[top_df['Golden_Ratio'].idxmax(),'Country_Name']
print("Top Country is", top_country_gold, "with a ratio of %.2f" %top_max_ratio)
# Out:
# Maximum Gold Ratio is 0.4049429657794677
# Top Country is China with a ratio of 0.40

# %%
#Findin best overall performer with maximum number of gold medals

#Removing the last column of the dataframe
data_1 = data[:-1]
data_1.tail(5)
# Out:
#                          Country_Name  # Summer  Gold_Summer  Silver_Summer  \
# 141                        Yugoslavia        16           26             29
# 142  Independent Olympic Participants         1            0              1
# 143                            Zambia        12            0              1
# 144                          Zimbabwe        12            3              4
# 145                        Mixed team         3            8              5
#
#      Bronze_Summer  Total_Summer  # Winter  Gold_Winter  Silver_Winter  \
# 141             28            83        14            0              3
# 142              2             3         0            0              0
# 143              1             2         0            0              0
# 144              1             8         1            0              0
# 145              4            17         0            0              0
#
#      Bronze_Winter  Total_Winter  # Games  Gold_Total  Silver_Total  \
# ...

# %%
#Creating a new column 'Total_Points'
data_1['Total_Points'] = data_1['Gold_Total']*3 + data_1['Silver_Total']*2 + data_1['Bronze_Total']*1
data_1.head(10)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   Country_Name  # Summer  Gold_Summer  Silver_Summer  Bronze_Summer  \
# 0  Afghanistan        13            0              0              2
# 1      Algeria        12            5              2              8
# 2    Argentina        23           18             24             28
# 3      Armenia         5            1              2              9
# 4  Australasia         2            3              4              5
# 5    Australia        25          139            152            177
# 6      Austria        26           18             33             35
# 7   Azerbaijan         5            6              5             15
# ...

# %%
#Finding the maximum value of 'Total_Points' column
most_points = max(data_1['Total_Points'])
print("Most Points in Olympics are",most_points)

#Finding the country assosciated with the max value of 'Total_Column' column
best_country = data_1.loc[data_1['Total_Points'].idxmax(),'Country_Name']
print('The maximum points achieved is', most_points, 'by', best_country)
# Out:
# Most Points in Olympics are 5684
# The maximum points achieved is 5684 by United States

# %%
#plotting visualisation for best country

#Subsetting the dataframe
best = data[data['Country_Name'] == best_country]
best.reset_index(drop = True, inplace = True)
best=best[['Gold_Total','Silver_Total','Bronze_Total']]
best
# Out:
#    Gold_Total  Silver_Total  Bronze_Total
# 0        1072           859           750

# %%
#Plotting bar plot
best.plot.bar(stacked=False)

#Changing the x-axis label
plt.xlabel('United States')

#Changing the y-axis label
plt.ylabel('Medals Tally')

#Rotating the ticks of X-axis
plt.xticks(rotation=45)

#Updating the graph legend
l=plt.legend()
l.get_texts()[0].set_text('Gold_Total :' + str(best['Gold_Total'].values))
l.get_texts()[1].set_text('Silver_Total :' + str(best['Silver_Total'].values))
l.get_texts()[2].set_text('Bronze_Total :' + str(best['Bronze_Total'].values))
